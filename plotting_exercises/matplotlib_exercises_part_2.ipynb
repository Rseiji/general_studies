# %% [markdown]
# # Matplotlib Exercises - Part 2
#
# [Matplotlib Exercises - pynative](https://pynative.com/python-matplotlib-exercise/)
#
# 3. [Machinelearningplus - 50 matplotlib visualizations](https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/#44.-Area-Chart-UnStacked)

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
df = pd.read_csv('company_sales_data.csv')

# %%
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# # Exercise 1: Read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following properties: –
#
# X label name = Month Number
# Y label name = Total profit

# %%
df.plot(x='month_number', y='total_profit')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.title('Company profit per month')
# Out:
# Text(0.5, 1.0, 'Company profit per month')

# %% [markdown]
# # Exercise 2: Get total profit of all months and show line plot with the following Style properties
# Generated line plot must include following Style properties:
#
# * Line Style dotted and Line-color should be red
# * Show legend at the lower right location.
# * X label name = Month Number
# * Y label name = Sold units number
# * Add a circle marker.
# * Line marker color as read
# * Line width should be 3

# %%
df.plot(x='month_number', y='total_profit', ls='--', color='red', lw=3, marker='o', markerfacecolor='black')
plt.legend(loc='lower right')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.title('Company profit per month')
# Out:
# Text(0.5, 1.0, 'Company profit per month')

# %% [markdown]
# # Exercise 3: Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
df.plot(
    x='month_number',
    y=['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer'],
    color=['blue', 'orange', 'green', 'red', 'purple', 'brown'],
    lw=3,
    marker='o',
    figsize=(10,5)
)
plt.legend(loc='upper left')
plt.xlabel('Month Number', fontsize=15)
plt.ylabel('Sales units in number', fontsize=15)
plt.title('Sales Data', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Sales Data')

# %% [markdown]
# # Exercise 4: Read toothpaste sales data of each month and show it using a scatter plot
# Also, add a grid in the plot. gridline style should “–“.
#
# The scatter plot should look like this.

# %%
plt.scatter(df['month_number'].tolist(), df['toothpaste'].tolist())
plt.xlabel('Month Number', fontsize=15)
plt.ylabel('Nmuber of units sold', fontsize=15)
plt.title('Tooth Paste Sales Data', fontsize=20)
plt.legend()
# Out:
# No handles with labels found to put in legend.
